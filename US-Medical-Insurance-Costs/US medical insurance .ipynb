# %% [markdown]
# # US Medical Insurance Costs
# In this project I shall be analyzing the medical insurance cost that occur in the US. There are multiple variables like Gender, Age, Location, Smoker status and bmi's. I will be using a CSV file that I will link in the bottom of the project. -Aditya Tekale

# %% [markdown]
# I'll start with organizing the data first so as to make the whole analysis process easier.

# %%
#importing csv file
import os
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir(r"C:\Users\tekal\Downloads")
data = pd.read_csv("insurance.csv")

# %%
#I'll be printing out the data to get an idea of what the data is about.
print(data)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# This Data has 1338 rows and 7 columns. In this given data we can see that 4 columns are quantitative and 3 columns are qualitative. The data is also not organized properly which I'll work on in next steps.

# %%
#Code to show number of rows and coloumns in csv file using pandas library
df1 = pd.read_csv('insurance.csv')
result = df.shape
print("Number of rows and columns of the Data:")
print(result)
# Out:
# Number of rows and columns of the Data:
# (1338, 7)

# %%
#Creating empty lists for the various attributes in csv
age = []
sex = []
bmi = []
children = []
smoker_status = []
region = []
insurance_charge = []

# %%
# helper function to load csv data which helps in organizing the data 
def data_list(lst, csv_file, column_name):
    # open csv file
    with open('insurance.csv') as csv_info:
        # read the data from the csv file
        csv_dict = csv.DictReader(csv_info)
        # loop through the data in each row of the csv 
        for row in csv_dict:
            # add the data from each row to a list
            lst.append(row[column_name])
        # return the list
        return lst

# %%
# this is to put the data in the respective columns
data_list(age, 'insurance.csv', 'age')
data_list(sex, 'insurance.csv', 'sex')
data_list(bmi, 'insurance.csv', 'bmi')
data_list(children, 'insurance.csv', 'children')
data_list(smoker_status, 'insurance.csv', 'smoker')
data_list(region, 'insurance.csv', 'region')
data_list(insurance_charge, 'insurance.csv', 'charges')
# Out:
# ['16884.924',
#  '1725.5523',
#  '4449.462',
#  '21984.47061',
#  '3866.8552',
#  '3756.6216',
#  '8240.5896',
#  '7281.5056',
#  '6406.4107',
#  '28923.13692',
#  '2721.3208',
#  '27808.7251',
#  '1826.843',
#  '11090.7178',
#  '39611.7577',
#  '1837.237',
#  '10797.3362',
#  '2395.17155',
#  '10602.385',
#  '36837.467',
#  '13228.84695',
#  '4149.736',
#  '1137.011',
#  '37701.8768',
#  '6203.90175',
#  '14001.1338',
#  '14451.83515',
#  '12268.63225',
#  '2775.19215',
#  '38711',
#  '35585.576',
#  '2198.18985',
#  '4687.797',
#  '13770.0979',
#  '51194.55914',
#  '1625.43375',
#  '15612.19335',
#  '2302.3',
#  '39774.2763',
#  '48173.361',
#  '3046.062',
#  '4949.7587',
#  '6272.4772',
#  '6313.759',
#  '6079.6715',
#  '20630.28351',
#  '3393.35635',
#  '3556.9223',
#  '12629.8967',
#  '38709.176',
#  '2211.13075',
#  '3579.8287',
#  '23568.272',
#  '37742.5757',
#  '8059.6791',
#  '47496.49445',
#  '13607.36875',
#  '34303.1672',
#  '23244.7902',
#  '5989.52365',
# ...

# %%
class PatientsInfo:
    # init method that takes in each list parameter
    def __init__(self, patients_ages, patients_sexes, patients_bmis, patients_num_children, 
                 patients_smoker_statuses, patients_regions, patients_charges):
        self.patients_ages = patients_ages
        self.patients_sexes = patients_sexes
        self.patients_bmis = patients_bmis
        self.patients_num_children = patients_num_children
        self.patients_smoker_statuses = patients_smoker_statuses
        self.patients_regions = patients_regions
        self.patients_charges = patients_charges

    # method that calculates the average ages of the patients in insurance.csv
    def analyze_ages(self):
        # initialize total age at zero
        total_age = 0
        # iterate through all ages in the ages list
        for age in self.patients_ages:
            # sum of the total age
            total_age += int(age)
        # return total age divided by the length of the patient list
        return ("Average Patient Age: " + str(round(total_age/len(self.patients_ages), 2)) + " years")

    # method that calculates the number of males and females in insurance.csv
    def analyze_sexes(self):
        # initialize number of males and females to zero
        females = 0
        males = 0
        # iterate through each sex in the sexes list
        for sex in self.patients_sexes:
            # if female add to female variable
            if sex == 'female':
                females += 1
            # if male add to male variable
            elif sex == 'male':
                males += 1
        # print out the number of each
        print("Count for female: ", females, "and Count for male: ", males )

    # method to find each unique region patients are from
    def unique_regions(self):
        # initialize empty list
        unique_regions = []
        # iterate through each region in regions list
        for region in self.patients_regions:
            # if the region is not already in the unique regions list
            # then add it to the unique regions list
            if region not in unique_regions: 
                unique_regions.append(region)
        # return unique regions list
        return unique_regions

    # method to find average yearly medical charges for patients in insurance.csv
    def average_charges(self):
        # initialize total_charges variable
        total_charges = 0
        # iterate through charges in patients charges list
        # add each charge to total_charge
        for charge in self.patients_charges:
            total_charges += float(charge)
        # return the average charges rounded to the hundredths place
        return ("Average Yearly Medical Insurance Charges: " +  
                str(round(total_charges/len(self.patients_charges), 2)) + " dollars.")
    
    # method to create dictionary with all patients information
    def create_dictionary(self):
        self.patients_dictionary = {}
        self.patients_dictionary["age"] = [int(age) for age in self.patients_ages]
        self.patients_dictionary["sex"] = self.patients_sexes
        self.patients_dictionary["bmi"] = self.patients_bmis
        self.patients_dictionary["children"] = self.patients_num_children
        self.patients_dictionary["smoker"] = self.patients_smoker_statuses
        self.patients_dictionary["regions"] = self.patients_regions
        self.patients_dictionary["charges"] = self.patients_charges
        return self.patients_dictionary

# %%
patient_info = PatientsInfo(age, sex, bmi, children, smoker_status, region, insurance_charge)

# %%
print(patient_info.analyze_ages())
print("Regions: ", patient_info.unique_regions())
print(patient_info.average_charges())
patient_info.analyze_sexes()
# Out:
# Average Patient Age: 39.21 years
# Regions:  ['southwest', 'southeast', 'northwest', 'northeast']
# Average Yearly Medical Insurance Charges: 13270.42 dollars.
# Count for female:  662 and Count for male:  676

# %% [markdown]
# Now the whole data is organized and I'll move forward with my analysis.

# %% [markdown]
# # Analysis

# %% [markdown]
# 1) Finding out what age groups of individuals are visting the hospital more

# %%
sns.displot(df['age'], kde = False, bins = 10, color = 'brown')
plt.xlabel('Age of Individuals')
plt.ylabel('Number of people')
# Out:
# Text(3.674999999999997, 0.5, 'Number of people')

# %% [markdown]
# This is the histogram which shows us the age frequency of individuals. From the given hsitogram we can interpret that there are more higher younger demograhic visiting the hospital, My next analysis would be to find out why are the youngers ones visting the hospital more than older age groups.

# %% [markdown]
# From the above graph and given data we can assume that it is either because of smoking or BMI which is why younger age demographics is visting the hospital more, next two analysis will be to find out which of this two is true.

# %%
sns.histplot(data = data, x='age', y = 'smoker', shrink=.9, color = 'blue')
# Out:
# <AxesSubplot:xlabel='age', ylabel='smoker'>

# %% [markdown]
# From this analysis of comparing age and smokers, we can interpret that smoking doesnt seem to be very high contributing factor for the vistis of younger age demograhic compared to older age demographics, which leaves us with BMI that can help us understand if BMI (Body Mass Index) has something to do with the more visits of younger demographic to the hospital.

# %%
sns.jointplot(x =df['age'], y = df['bmi'], kind = 'hex', bins = 10, color = 'red')

# %% [markdown]
# From this analysis we can interpret why the younger age demoraphic is visitng the hospital more than the older age demographic, the BMI's of younger age seems to be very high in the hex graph. BMI may be a concluding factor to more vistis to the hospital in younger age demographics.

# %% [markdown]
# 2) Find out which age group has highest insurance cost.(Create seaborn distribution plot using age buckets and cost of insurance)

# %%
#creating age buckets using pandas library
ages = pd.DataFrame(data, columns=['age', 'charges'])

bins = [10, 20, 30, 40, 50, 60, 70, 80]
labels = ['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71+']
ages['age-range'] = pd.cut(ages.age, bins, labels = labels,include_lowest = True)
df2 = ages
print(df2)
# Out:
#       age      charges age-range
# 0      19  16884.92400      0-20
# 1      18   1725.55230      0-20
# 2      28   4449.46200     21-30
# 3      33  21984.47061     31-40
# 4      32   3866.85520     31-40
# ...   ...          ...       ...
# 1333   50  10600.54830     41-50
# 1334   18   2205.98080      0-20
# 1335   18   1629.83350      0-20
# 1336   21   2007.94500     21-30
# 1337   61  29141.36030     61-70
#
# [1338 rows x 3 columns]

# %%
sns.displot(data, x="age", y="charges")

# %% [markdown]
# From the above graph we can notice that the insurance charges are mostly below 20000
